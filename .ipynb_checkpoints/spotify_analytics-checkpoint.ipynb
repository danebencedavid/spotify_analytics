# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('dataset.csv',index_col=0)

# %%
df.shape
# Out:
# (114000, 20)

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# 25%         2.000000     -10.013000       0.000000       0.035900
# 50%         5.000000      -7.004000       1.000000       0.048900
# 75%         8.000000      -5.003000       1.000000       0.084500
# max        11.000000       4.532000       1.000000       0.965000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  114000.000000     114000.000000  114000.000000  114000.000000
# mean        0.314910          0.156050       0.213553       0.474068
# std         0.332523          0.309555       0.190378       0.259261
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.016900          0.000000       0.098000       0.260000
# 50%         0.169000          0.000042       0.132000       0.464000
# 75%         0.598000          0.049000       0.273000       0.683000
# max         0.996000          1.000000       1.000000       0.995000
#
#                tempo  time_signature
# count  114000.000000   114000.000000
# mean      122.147837        3.904035
# std        29.978197        0.432621
# min         0.000000        0.000000
# 25%        99.218750        4.000000
# 50%       122.017000        4.000000
# 75%       140.071000        4.000000
# max       243.372000        5.000000

# %%
df.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %%
pop = df['popularity']

# %%
df.loc[df['popularity'] == 100]
# Out:
#                      track_id               artists  \
# 20001  3nqQXoyQOWXiESFLlDF1hG  Sam Smith;Kim Petras
# 81051  3nqQXoyQOWXiESFLlDF1hG  Sam Smith;Kim Petras
#
#                       album_name                 track_name  popularity  \
# 20001  Unholy (feat. Kim Petras)  Unholy (feat. Kim Petras)         100
# 81051  Unholy (feat. Kim Petras)  Unholy (feat. Kim Petras)         100
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 20001       156943     False         0.714   0.472    2    -7.375     1
# 81051       156943     False         0.714   0.472    2    -7.375     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 20001       0.0864         0.013          0.000005     0.266    0.238
# 81051       0.0864         0.013          0.000005     0.266    0.238
#
#          tempo  time_signature track_genre
# 20001  131.121               4       dance
# 81051  131.121               4         pop

# %%
plt.hist(pop,bins=range(101),log=True);
plt.ylabel("Number of Tracks");
plt.xlabel("Popularity");
plt.title("Popularity Distribution");
plt.xticks(range(0,101,5));

# %%
# Energy and Popularity

# %%
# Energy is a value between 0 and 1, while popularity is between 0 and 100
# Can more energetic tracks become popular?

# %%
high_energy = (len(df[df['energy'] >= 0.7]) / len(df)) * 100

# %%
high_energy_pop = df[df['energy'] >= 0.7]['popularity'].mean()

# %%
low_energy = (len(df[df['energy'] <= 0.5]) / len(df)) * 100

# %%
low_energy_pop = df[df['energy'] <= 0.5]['popularity'].mean()

# %%
plt.bar(["High Energy","Low Energy"],[high_energy_pop,low_energy_pop]);

# %%
energy_pop = df[df['popularity']>= 70]['energy']
energy_npop = df[df['popularity']<= 50]['energy']
label = ['Popular','Less Popular']
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([energy_pop, energy_npop], labels=label);
ax.set_xlabel('Popularity Category')
ax.set_ylabel('Energy')
ax.set_title('Energy Distribution by Popularity Category');
y_ticks = np.arange(0,1.1,0.1)
ax.set_yticks(y_ticks);

# %% [markdown]
# ***Artist Analysis***

# %%
# Finding the top 10 artists with the most tracks and 
#calcualting their average popularity

# %%
grouped = df.groupby(['artists']).agg({'artists':'first','track_id':'count','popularity':'mean'})

# %%
result = grouped.sort_values('track_id',ascending=False).head(10)

# %%
plt.bar(result['artists'],result['track_id']);
plt.ylabel('Tracks published')
plt.xlabel('Artists')
plt.xticks(result['artists'],rotation=40,size=7);
plt.show()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(result['artists'],result['track_id'],color='b');
ax2.plot(result['artists'],result['popularity'],color='r');

ax1.set_xlabel('Artists')
ax1.set_ylabel('Tracks published', color='b')
ax2.set_ylabel('Popularity', color='r')
ax1.set_xticklabels(result['artists'], rotation='vertical', size=7)

fig.show()
# Out:
# C:\Users\Bence\AppData\Local\Temp\ipykernel_2368\2291982605.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(result['artists'], rotation='vertical', size=7)
# C:\Users\Bence\AppData\Local\Temp\ipykernel_2368\2291982605.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ***Album Analysis***

# %%
#Selecting the top 10 most popular albums.
a = df.groupby(['album_name']).agg({'album_name':'first','duration_ms':'mean','popularity':'mean'})
a = a.sort_values('popularity',ascending=False).head(10)

# %%
a['minutes'] = round((a['duration_ms'] / 1000)/60,3)

# %%
a
# Out:
#                                                                                            album_name  \
# album_name
# Unholy (feat. Kim Petras)                                                   Unholy (feat. Kim Petras)
# Quevedo: Bzrp Music Sessions, Vol. 52                           Quevedo: Bzrp Music Sessions, Vol. 52
# La Bachata                                                                                 La Bachata
# Indigo (Extended)                                                                   Indigo (Extended)
# I Ain’t Worried (Music From The Motion Picture ...  I Ain’t Worried (Music From The Motion Picture...
# RENAISSANCE                                                                               RENAISSANCE
# PROVENZA                                                                                     PROVENZA
# Harry's House                                                                           Harry's House
# Super Freaky Girl                                                                   Super Freaky Girl
# Calm Down (with Selena Gomez)                                           Calm Down (with Selena Gomez)
#
#                                                     duration_ms  popularity  \
# album_name
# Unholy (feat. Kim Petras)                              156943.0       100.0
# Quevedo: Bzrp Music Sessions, Vol. 52                  198937.0        99.0
# La Bachata                                             162637.0        98.0
# Indigo (Extended)                                      184613.0        96.0
# I Ain’t Worried (Music From The Motion Picture ...     148485.0        96.0
# RENAISSANCE                                            225388.0        93.0
# PROVENZA                                               210200.0        93.0
# Harry's House                                          167303.0        92.0
# Super Freaky Girl                                      170977.0        92.0
# Calm Down (with Selena Gomez)                          239317.0        92.0
#
#                                                     minutes
# album_name
# Unholy (feat. Kim Petras)                             2.616
# Quevedo: Bzrp Music Sessions, Vol. 52                 3.316
# La Bachata                                            2.711
# Indigo (Extended)                                     3.077
# I Ain’t Worried (Music From The Motion Picture ...    2.475
# RENAISSANCE                                           3.756
# PROVENZA                                              3.503
# Harry's House                                         2.788
# Super Freaky Girl                                     2.850
# Calm Down (with Selena Gomez)                         3.989

# %%
plt.scatter(a['minutes'],a['popularity']);
plt.xlabel('Track lenght in minutes');
plt.ylabel('Popularity');
plt.title('Most popular tracks with their average length');

# %% [markdown]
# **Explicit Analysis**

# %%
exp_percY = (len(df[df['explicit'] == True]) / len(df)) * 100
exp_percN = 100-exp_percY
exp_labels = ['Explicit', 'Not explicit']
explode = (0.1,0)
fig,ax = plt.subplots()
ax.pie([exp_percY,exp_percN],labels=exp_labels,autopct='%1.1f%%',colors=["#4FB286","#7692FF"],explode = explode);

# %%
exp_avg = df.groupby(['explicit']).agg({'explicit':'first','popularity':'mean'})
exp_avg
# Out:
#           explicit  popularity
# explicit
# False        False   32.937891
# True          True   36.454191

# %%
exp_avg['explicit'] = exp_avg['explicit'].replace({True: 'True', False: 'False'})

# %%
plt.bar(exp_avg['explicit'],exp_avg['popularity'],width=0.42,label=exp_avg['explicit']);
plt.ylabel('Popularity');
plt.xlabel('Whether the track has explicit lyrics');

# %% [markdown]
# **Key and Mode Analysis**

# %%
most_key = df.groupby(['key']).agg({'key':'first','track_id':'count'})
most_key_a = most_key.replace({0:'C',1:'C#',2:'D',3:'D#',4:'E',5:'E#',6:'F',7:'F#',8:'G',9:'G#',10:'A',11:'A#'})

# %%
plt.bar(most_key_a['key'],most_key_a['track_id']);

# %%
minor = (len(df[df['mode']== 0])/len(df))*100
major = (len(df[df['mode']== 1])/len(df))*100

# %%
mode_labels = ['Minor','Major']
fig,ax = plt.subplots()
ax.pie([minor,major],labels = mode_labels,colors=["#F45B69","#854798"],autopct='%1.1f%%');

# %% [markdown]
# **Liveness Analysis**

# %%
#A value above 0.8 provides strong likelihood 
#that the track is live
df['liveness']
# Out:
# 0         0.3580
# 1         0.1010
# 2         0.1170
# 3         0.1320
# 4         0.0829
#            ...
# 113995    0.0863
# 113996    0.1050
# 113997    0.0839
# 113998    0.2700
# 113999    0.0893
# Name: liveness, Length: 114000, dtype: float64

# %%
live_perc = (len(df[df['liveness'] >= 0.8])/len(df)) * 100

# %%
live_grouped = df.groupby(['liveness']).apply(lambda x: x[x['liveness'] >= 0.8])['liveness']

# %%
n_live_grouped = df.groupby(['liveness']).apply(lambda x: x[x['liveness'] < 0.8])['liveness']

# %%
labels = ['Popularity of Live tracks','Popularity of not live tracks']
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([live_grouped, n_live_grouped], labels=labels,flierprops={'markersize':1});
ax.set_ylabel('Popularity')
ax.set_title('Popularity for Live and Not live tracks');
y_ticks = np.arange(0,1.1,0.1)
ax.set_yticks(y_ticks);
ax.yaxis.grid(True)
